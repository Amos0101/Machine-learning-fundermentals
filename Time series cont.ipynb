# %%
import pandas as pd

df = pd.read_csv("AAPL_NO_DATES.csv")
df.head(5)
# Out:
#          Open        High         Low       Close   Adj Close     Volume
# 0  196.240005  196.729996  195.279999  195.610001  194.576660   35175100
# 1  195.039993  195.179993  191.850006  192.580002  191.562653   50389300
# 2  191.570007  192.369995  190.690002  191.169998  190.160110   61235200
# 3  185.520004  187.380005  181.919998  181.990005  181.028610  115799700
# 4  182.130005  183.130005  177.350006  178.850006  177.905197   97576100

# %%
rng = pd.date_range(start = "2023-08-01",end = "2023-08-31",freq = "B")
rng
# Out:
# DatetimeIndex(['2023-08-01', '2023-08-02', '2023-08-03', '2023-08-04',
#                '2023-08-07', '2023-08-08', '2023-08-09', '2023-08-10',
#                '2023-08-11', '2023-08-14', '2023-08-15', '2023-08-16',
#                '2023-08-17', '2023-08-18', '2023-08-21', '2023-08-22',
#                '2023-08-23', '2023-08-24', '2023-08-25', '2023-08-28',
#                '2023-08-29', '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', freq='B')

# %%
df.set_index(rng,inplace = True)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2023-08-01  196.240005  196.729996  195.279999  195.610001  194.576660
# 2023-08-02  195.039993  195.179993  191.850006  192.580002  191.562653
# 2023-08-03  191.570007  192.369995  190.690002  191.169998  190.160110
# 2023-08-04  185.520004  187.380005  181.919998  181.990005  181.028610
# 2023-08-07  182.130005  183.130005  177.350006  178.850006  177.905197
# 2023-08-08  179.690002  180.270004  177.580002  179.800003  178.850159
# 2023-08-09  180.869995  180.929993  177.009995  178.190002  177.248672
# 2023-08-10  179.479996  180.750000  177.600006  177.970001  177.029861
# 2023-08-11  177.320007  178.619995  176.550003  177.789993  177.089615
# 2023-08-14  177.970001  179.690002  177.309998  179.460007  178.753036
# 2023-08-15  178.880005  179.479996  177.050003  177.449997  176.750946
# 2023-08-16  177.130005  178.539993  176.500000  176.570007  175.874420
# ...

# %%
# %matplotlib inline

df.Close.plot()
# Out:
# <Axes: >

# %%
df["2023-08-01":"2023-08-10"].Close.mean()
# Out:
# np.float64(184.52000225)

# %%
df.asfreq('h',method = "pad").Close.plot()
# Out:
# <Axes: >

# %%
rng = pd.date_range(start = '2020-10-01',periods = 80,freq = 'B')
rng
# Out:
# DatetimeIndex(['2020-10-01', '2020-10-02', '2020-10-05', '2020-10-06',
#                '2020-10-07', '2020-10-08', '2020-10-09', '2020-10-12',
#                '2020-10-13', '2020-10-14', '2020-10-15', '2020-10-16',
#                '2020-10-19', '2020-10-20', '2020-10-21', '2020-10-22',
#                '2020-10-23', '2020-10-26', '2020-10-27', '2020-10-28',
#                '2020-10-29', '2020-10-30', '2020-11-02', '2020-11-03',
#                '2020-11-04', '2020-11-05', '2020-11-06', '2020-11-09',
#                '2020-11-10', '2020-11-11', '2020-11-12', '2020-11-13',
#                '2020-11-16', '2020-11-17', '2020-11-18', '2020-11-19',
#                '2020-11-20', '2020-11-23', '2020-11-24', '2020-11-25',
#                '2020-11-26', '2020-11-27', '2020-11-30', '2020-12-01',
#                '2020-12-02', '2020-12-03', '2020-12-04', '2020-12-07',
#                '2020-12-08', '2020-12-09', '2020-12-10', '2020-12-11',
# ...

# %%
import numpy as np

ts = pd.Series(np.random.randint(1,10,len(rng)), index = rng)
ts
# Out:
# 2020-10-01    2
# 2020-10-02    6
# 2020-10-05    1
# 2020-10-06    2
# 2020-10-07    5
#              ..
# 2021-01-14    2
# 2021-01-15    7
# 2021-01-18    4
# 2021-01-19    8
# 2021-01-20    9
# Freq: B, Length: 80, dtype: int32
