# %%
import pandas as pd

df = pd.read_csv("AAPL.csv",parse_dates=["Date"],index_col="Date")
df.head(5)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-07-11  189.160004  189.300003  186.600006  188.080002  187.086426
# 2023-07-12  189.679993  191.699997  188.470001  189.770004  188.767502
# 2023-07-13  190.500000  191.190002  189.779999  190.539993  189.533432
# 2023-07-14  190.229996  191.179993  189.630005  190.690002  189.682663
# 2023-07-17  191.899994  194.320007  191.809998  193.990005  192.965225
#
#               Volume
# Date
# 2023-07-11  46638100
# 2023-07-12  60750200
# 2023-07-13  41342300
# 2023-07-14  41573900
# 2023-07-17  50520200

# %%
df.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.index
#
# NameError: name 'df' is not defined

# %%
df["2023-10"]

# %%
# %matplotlib inline
df.Close.resample('ME').mean().plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 df.Close.resample('ME').mean().plot()
#
# NameError: name 'df' is not defined

# %%
# %matplotlib inline
df.Close.resample('ME').mean().plot(kind="bar")# mean in each month
# Out:
# <Axes: xlabel='Date'>

# %%
# %matplotlib inline
df.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined
