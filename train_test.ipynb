# %%
import pandas as pd
df = pd.read_csv("train_test.csv")
df.head()
# Out:
#    mileage  age  price
# 0    63000    8  15000
# 1    59000    5  17000
# 2    78000    2  14000
# 3    45000    9  27000
# 4    96000    8  32000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df["mileage"],df["price"],color ="red")

# %%
plt.scatter(df["age"],df["price"])

# %%
X = df[["mileage","age"]]
y = df["price"]

# %%
X
# Out:
#    mileage  age
# 0    63000    8
# 1    59000    5
# 2    78000    2
# 3    45000    9
# 4    96000    8
# 5    56000    4
# 6    87000    6
# 7    36000    7
# 8    59000    9
# 9    90000    5

# %%
y
# Out:
# 0    15000
# 1    17000
# 2    14000
# 3    27000
# 4    32000
# 5    26000
# 6    32000
# 7    19000
# 8    14000
# 9    25000
# Name: price, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
len(y_test)
# Out:
# 2

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg.predict(X_test)
# Out:
# array([29607.81815744, 20847.92812123])

# %%
y_test
# Out:
# 9    25000
# 8    14000
# Name: price, dtype: int64

# %%
reg.score(X_test,y_test) # model accuracy
# Out:
# -0.126051367363752
